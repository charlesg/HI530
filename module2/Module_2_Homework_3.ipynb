# %% [markdown]
# # Module 2 - Homework 3
#
# ## Intro
#
# Create two network graphs similar to Figure 3.14. Use the Flight Delays data attached.
#
# ## Question 1
#
# For the first graph, use source as ORIGIN and target as CARRIER. What can you infer from this graph?

# %%
import numpy as np
import networkx as nx
import pandas as pd
import matplotlib.pylab as plt

# %%
fd_df = pd.read_csv('FlightDelays.csv')
fd_df
# Out:
#       CRS_DEP_TIME CARRIER  DEP_TIME DEST  DISTANCE     FL_DATE  FL_NUM  \
# 0             1455      OH      1455  JFK       184  01/01/2004    5935
# 1             1640      DH      1640  JFK       213  01/01/2004    6155
# 2             1245      DH      1245  LGA       229  01/01/2004    7208
# 3             1715      DH      1709  LGA       229  01/01/2004    7215
# 4             1039      DH      1035  LGA       229  01/01/2004    7792
# ...            ...     ...       ...  ...       ...         ...     ...
# 2196           645      RU       644  EWR       199   1/31/2004    2761
# 2197          1700      RU      1653  EWR       213   1/31/2004    2497
# 2198          1600      RU      1558  EWR       199   1/31/2004    2361
# 2199          1359      RU      1403  EWR       199   1/31/2004    2216
# 2200          1730      RU      1736  EWR       199   1/31/2004    2097
#
#      ORIGIN  Weather  DAY_WEEK  DAY_OF_MONTH TAIL_NUM Flight Status
# ...

# %%
G = nx.from_pandas_edgelist(fd_df, source='ORIGIN', target='CARRIER')
 
isCarrier = [n in set(fd_df.CARRIER) for n in G.nodes()]
pos = nx.spring_layout(G, k=0.13, iterations=60, scale=0.5)
plt.figure(figsize=(10,10))
nx.draw_networkx(G, pos=pos, with_labels=True,
                 edge_color='lightgray',
                 node_color=['gray' if carrier else 'black' for carrier in isCarrier],
                 node_size=[50 if carrier else 200 for carrier in isCarrier])
plt.axis('off')
plt.show()

# %% [markdown]
# ### Interpretation
#
# One airport (DCA), seems to have a lot more carriers than the other two airports (BWI and IAD). Two carriers (DH and RU) connect DCA to IAD while a single carrier, RU, connects DCA to BWI.

# %% [markdown]
# ## Question 2
#
# For the second graph, use source as DEST and target as CARRIER. What can you infer from this graph?

# %%
G = nx.from_pandas_edgelist(fd_df, source='DEST', target='CARRIER')
 
isCarrier = [n in set(fd_df.CARRIER) for n in G.nodes()]
pos = nx.spring_layout(G, k=0.13, iterations=60, scale=0.5)
plt.figure(figsize=(10,10))
nx.draw_networkx(G, pos=pos, with_labels=True,
                 edge_color='lightgray',
                 node_color=['gray' if carrier else 'black' for carrier in isCarrier],
                 node_size=[50 if carrier else 200 for carrier in isCarrier])
plt.axis('off')
plt.show()

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=52e9ae2e-8d42-48c9-9988-588f5a262306' target="_blank">
# <img style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
